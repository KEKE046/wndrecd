# %%
import re
import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('~/.wndrecd.txt', index_col=False, delimiter=',', names=['time', 'action', 'win'])
df = df.loc[df.action != ' scrunlock']
df.time = pd.to_datetime(df.time)
print(len(df))
# Out:
# 65

# %%
df_tmp = df.iloc[:-1].copy()
df_tmp['duration'] = df.time.diff().iloc[1:].to_numpy()
df = df_tmp; del df_tmp
df.head(10)
# Out:
#                       time     action  \
# 0  2022-02-05 12:21:11.784   activate
# 1  2022-02-05 12:21:21.189   activate
# 2  2022-02-05 12:21:22.266   activate
# 3  2022-02-05 12:21:27.160   activate
# 4  2022-02-05 12:21:28.769    scrlock
# 5  2022-02-05 12:21:31.586   activate
# 7  2022-02-05 12:21:32.952   activate
# 8  2022-02-05 12:21:40.814   activate
# 9  2022-02-05 12:21:46.187   activate
# 10 2022-02-05 12:21:49.156   activate
#
#                                             win               duration
# 0                          user : zsh — Yakuake 0 days 00:00:09.405000
# 1    main.cpp - record-wnd - Visual Studio Code 0 days 00:00:01.077000
# 2                          user : zsh — Yakuake 0 days 00:00:04.894000
# 3    main.cpp - record-wnd - Visual Studio Code 0 days 00:00:01.609000
# 4                                       scrlock 0 days 00:00:02.817000
# 5    main.cpp - record-wnd - Visual Studio Code 0 days 00:00:01.366000
# 7                          user : zsh — Yakuake 0 days 00:00:07.862000
# 8    main.cpp - record-wnd - Visual Studio Code 0 days 00:00:05.373000
# 9                          user : zsh — Yakuake 0 days 00:00:02.969000
# 10   main.cpp - record-wnd - Visual Studio Code 0 days 00:02:23.068000

# %%
def extract_ent(name):
    global mx_level
    name = name.strip(' ')
    tokens = re.split('\s+[—-]\s+', name)
    return ' == '.join(tokens[::-1])

# %%
df['win_type'] = df.win.apply(extract_ent)
duration = df.groupby('win_type').duration.sum()
win_df = pd.DataFrame({'pct': duration / duration.sum(), 'dur':duration})
win_df.head()
# Out:
#                                 pct                    dur
# win_type
# KSystemlog == Journald 日志  0.000232 0 days 00:00:01.183000
# Konsole <3>‎ == ~ : zsh    0.000144 0 days 00:00:00.734000
# Konsole == JupyterLab      0.000447 0 days 00:00:02.283000
# Konsole == pro : zsh       0.001623 0 days 00:00:08.288000
# Konsole == ~ : vim         0.012806 0 days 00:01:05.400000

# %%
tree = {}
count = 0
for k, v in win_df.iterrows():
    ptr = tree
    for d in k.split(' == '):
        if d not in ptr:
            ptr[d] = {'__name__': d}
            count += 1
        ptr = ptr[d]
    ptr['__pct__'] = v['pct']
    ptr['__dur__'] = v['dur']
S = 2 * math.pi
idx = 0
def visit(p, acc=0, d=0):
    global idx
    idx += 1
    pct, dur = None, None
    if '__pct__' in p:
        pct, dur = p['__pct__'], p['__dur__']
    for k, v in p.items():
        if k.startswith('__'):
            continue
        vpct, vdur = visit(v, acc + (pct or 0), d+1)
        pct = vpct if pct is None else pct + vpct
        dur = vdur if dur is None else dur + vdur
    if d > 0 and pct > 0.01:
        mid = (acc + pct / 2)
        plt.barh([d], [S * pct], [1], left=S * acc)
        rot = mid * 360
        if rot > 90 and rot < 270:
            rot = rot - 180
        plt.annotate(p['__name__'][:10], (S * mid, d), ha='center', va='center', rotation=rot)
    return pct, dur

# %%
# %matplotlib qt
fig, ax = plt.subplots(subplot_kw=dict(projection="polar"), figsize=(10, 10))
visit(tree)
ax.set_axis_off()
